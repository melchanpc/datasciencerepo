# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Melanie Chan**
# <br>
# Desired Occupation : Data Scientist

# %% [markdown]
# *I am interested in data science because I like to utilize and maximize my anlaytic skills. Furthermore, I want to contribute to organizations' business goals and add value to business acumen using data driven insights*

# %% [markdown]
# ### My code below is supposed to find the largest numbers among three numbers eg. 10,20,88

# %%
# Python program to find the largest number among the three input numbers

# change the values of num1, num2 and num3
# for a different result
num1 = 10
num2 = 20
num3 = 88

if (num1 >= num2) and (num1 >= num3):
    largest = num1
elif (num2 >= num1) and (num2 >= num3):
    largest = num2
else:
    largest = num3

print("The largest number is", largest)
# Out:
# The largest number is 88

# %% [markdown]
# ### Horizontal Separator
# This is the sentence above the horizontal separator
# ***
# This is the sentence below the horizontal separator
# <br>
#
# ### Bulleted list
# * Example of bullet list 1
# * Example of bullet list 2
# <br>
#
# ### Numbered list
# 1. Sentence 1
# 2. Sentence 2
# <br>
#
# ### Hyperlinks
# [click me appear in google](http://google.com)
